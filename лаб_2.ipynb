# %% [markdown]
# <a href="https://colab.research.google.com/github/Nicole9080/programming_2_lab/blob/main/%D0%BB%D0%B0%D0%B1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Задани_02_15.
# Выполнил: Манидарова Н.Ч.
# Группа: ЦИБ-251

p = int(input("Грузоподъемность грузовика (кг.) = "))
n = int(input("Количество предметов = "))
total = 0
for i in range(1, n + 1):
    mass = int(input(f"Масса {i}-го предмета (кг.) = "))
    total += mass

if total <= p:
    print("Да")
else:
    print("Нет")
